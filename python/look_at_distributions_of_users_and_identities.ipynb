# %%
import numpy as np

z = np.load("run_1_user_id_matrix.npy")

# %%
z.sum(axis=1).max()
# Out:
# 5647.0

# %%
import seaborn as sns
# %matplotlib inline
sns.set()

sns.distplot(z.sum(axis=1))

# %%
sns.distplot(np.log(z.sum(axis=1)-175))

# %%
np.log(z.sum(axis=1)-175).std()
# Out:
# 1.2177507

# %%
import numpy as np
np.exp(np.random.normal(4.86,1.22,10000))

# %%
sns.distplot(np.log(z.sum(axis=0)))

# %%
sns.distplot(z.sum(axis=0))

# %%
np.random.multinomial(1, [.1,.2,.3])
# Out:
# array([0, 0, 1])

# %%
import msgpack

p = msgpack.load(open("../output/run_1/sent_dat/tr_inds0.mpack"))

# %%
p[0]
# Out:
# {'i_100a': [[0.070025, '1*-0.0556+uv.i_100e*-0.0168+uv.i_100p*-0.0296']],
#  'i_100e': [[0.196164858276126,
#    '1*-0.1338+uv.i_100p*0.0327+uv.i_100a*-0.0168']],
#  'i_100p': [[0.15934822103894, '1*0.3286+uv.i_100e*0.0327+uv.i_100a*-0.0296']],
#  'i_101e': [[1.0, 6.78239891268]],
#  'i_105a': [[1.0, -2.70940840064]],
#  'i_105e': [[1.0, -6.68383136176]],
#  'i_105p': [[1.0, -7.1346051447]],
#  'i_106a': [[1.0, 0.902869466882],
#   [1.0, 0.486068174474],
#   [1.0, 4.07496545972],
#   [0.157562997418613, 'uv.i_106e*-0.0133+1*0.4041+uv.i_106p*-0.0979'],
#   [1.0, -1.83002449543],
#   [1.0, 2.70900840064],
#   [0.070025, 'uv.i_106e*-0.0104+1*-0.0441+uv.i_106p*-0.0239'],
#   [0.070025, 'uv.i_106e*-0.0104+1*-0.0441+uv.i_106p*-0.0239'],
#   [0.070025, 'uv.i_106e*-0.0098+1*-0.0548+uv.i_106p*-0.0288'],
#   [1.0, -3.12620969306],
#   [1.0, -1.837007741876],
#   [1.0, -3.29782640038],
#   [1.0, 2.84794216478],
#   [1.0, 5.1264558966],
#   [0.0311861702347893,
# ...
